# %%
conda install -c conda-forge wordcloud
# Out:
# ...
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
from wordcloud import WordCloud
import PIL.Image as image
from PIL import Image 
import numpy as np
import matplotlib.pyplot as plt

# %%
path = r'/Users/jin/Desktop/SEM_A/5507-data-acquisition/Group-Assignment/last-coding/ciyuntu428.csv'
f = open(path,encoding='utf-8')
txt = f.read()

# %%
txt
# Out:
# ',words\n0,刚刚\n1,已经\n2,所有\n3,山寨币\n4,卖\n5,全冲\n6,狗狗币\n7,over\n8,愿意\n9,一起\n10,注意\n11,风险\n12,控制\n13,8\n14,号\n15,之前\n16,上升\n17,空间\n18,很大\n19,现在\n20,市值\n21,已经\n22,排\n23,第一\n24,越多人\n25,买\n26,涨\n27,越\n28,快\n29,愿意\n30,狗子\n31,币\n32,赌\n33,未来\n34,男朋友\n35,山寨币\n36,卖\n37,全部\n38,安排\n39,狗狗币\n40,狗狗币\n41,狗狗币\n42,大涨\n43,nL\n44,富婆\n45,本人\n46,没错\n47,狗狗币\n48,n1\n49,.\n50,不能\n51,做空\n52,狗狗币\n53,会\n54,倾家荡产\n55,n2\n56,.\n57,买\n58,一枚\n59,狗狗币\n60,留给\n61,孩子\n62,n3\n63,.\n64,人生\n65,建议\n66,不\n67,赌\n68,不\n69,嫖\n70,不\n71,吸毒\n72,坚持\n73,定\n74,投\n75,狗狗币\n76,n4\n77,.\n78,人生\n79,如戏\n80,唯有\n81,爱\n82,狗狗币\n83,不可\n84,辜负\n85,很多\n86,人\n87,问\n88,购买\n89,狗狗币\n90,最新\n91,最\n92,详细\n93,教程\n94,火火\n95,狗狗币\n96,大涨\n97,##\n98,购买\n99,狗狗币\n100,买\n101,狗狗币\n102,L\n103,会火\n104,大叔\n105,老\n106,韭菜\n107,老\n108,觉得\n109,有庄\n110,要害\n111,简单\n112,无脑\n113,送\n114,钱\n115,行情\n116,全\n117,踏空\n118,亏钱\n119,行情\n120,复杂\n121,没\n122,落下\n123,狗狗币\n124,狗狗币\n125,大涨\n126,##\n127,狗狗币\n128,狗狗币\n129,上涨\n130,不知道\n131,买\n132,看下\n133,这条\n134,评论\n135,狗狗币\n136,再次\n137,领涨\n138,到
# ...

# %%
#Backgroud image loading.
#设置背景图片。
background = Image.open("doge.jpg")
graph = np.array(background)

# %%
wcd=WordCloud(font_path=r'/Users/jin/Desktop/SEM_A/5507-data-acquisition/Group-Assignment/last-coding/SourceHanSansCN-Heavy.otf',
              collocations=False,
              width=500,
              height=400,
              background_color='white',
              max_words=100,
              mask=graph,
              scale=1.5).generate(txt)

# %%
wcd.generate(txt)

# %%
wcd.to_file(r"wordcloud428.png")

# %%
#Check image format figure.
# 查看图片制式特征
plt.figure("test")

# %%
plt.imshow(wcd)
