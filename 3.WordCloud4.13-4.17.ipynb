# %%
conda install -c conda-forge wordcloud
# Out:
# ...
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install jieba
from wordcloud import WordCloud
import PIL.Image as image
import numpy as np
import matplotlib.pyplot as plt
import os
from os import path
import jieba

# %%
path = r'/Users/jin/Desktop/SEM_A/5507-data-acquisition/Group-Assignment/last-coding/ciyuntu0413.csv'
f = open(path,encoding='utf-8')
txt = f.read()

# %%
txt
# Out:
# ',words\n0,狗狗币\n1,大涨\n2,深圳\n3,卧虎藏龙\n4,那天\n5,喝茶\n6,旁边\n7,坐\n8,两个\n9,人\n10,聊\n11,狗狗币\n12,现在\n13,想来\n14,他俩\n15,两天\n16,脸\n17,笑\n18,烂\n19,狗狗币\n20,买\n21,疯狂\n22,单日\n23,暴拉\n24,200%\n25,狗狗币\n26,一年\n27,狂飙\n28,180\n29,倍\n30,泡沫\n31,恐将\n32,破裂\n33,CoinMarketCap\n34,.\n35,com\n36,数据\n37,狗狗币\n38,埃隆\n39,马斯克\n40,马克\n41,库班\n42,人\n43,推动\n44,下\n45,周五\n46,4\n47,16\n48,一度\n49,上涨\n50,超\n51,200%\n52,目前\n53,狗狗币\n54,总\n55,市值\n56,超\n57,490\n58,亿美元\n59,超越\n60,稳定\n61,币\n62,USDT\n63,排名\n64,加密\n65,货币\n66,市值\n67,第五\n68,一年\n69,前\n70,0.002\n71,美元\n72,2.5\n73,亿美元\n74,相比\n75,现在\n76,上涨\n77,18000%\n78,疯狂\n79,这一\n80,加密\n81,货币\n82,单日\n83,暴拉\n84,200%\n85,一年\n86,狂飙\n87,18000%\n88,泡沫\n89,恐将\n90,破裂\n91,狗狗币\n92,1.2\n93,美元\n94,第三\n95,目标\n96,目标\n97,0.75\n98,第一\n99,目标\n100,0.48\n101,请\n102,相信\n103,反正\n104,不会买\n105,看戏\n106,好\n107,狗狗币\n108,狗狗币\n109,火\n110,一种\n111,比特币\n112,类似\n113,Doge\n114,Coin\n115,狗狗币\n116,加密\n117,货币\n118,最近\n119,疯长\n120,4\n121,16\n122,狗狗币\n123,日内\n124,涨幅\n125,超\n126,200%\n127,报\n128,0.397\n129,美元\n130,枚\n131,狗狗币\n
# ...

# %%
from PIL import Image 
background = Image.open("dollar-.jpg")
graph = np.array(background)

# %%
wcd=WordCloud(font_path=r'/Users/jin/Desktop/SEM_A/5507-data-acquisition/Group-Assignment/last-coding/SourceHanSansCN-Heavy.otf',
              collocations=False,
              width=500,
              height=400,
              background_color='white',
              max_words=100,
              mask=graph,
              scale=1.5).generate(txt)

# %%
wcd.generate(txt)

# %%
wcd.to_file(r"wordcloud0413.png")

# %%
plt.figure("jay")
# 以图片的形式显示词云

# %%
plt.imshow(wcd)
