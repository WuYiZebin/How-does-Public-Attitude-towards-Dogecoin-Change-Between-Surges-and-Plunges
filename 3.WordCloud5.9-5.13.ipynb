# %%
conda install -c conda-forge wordcloud
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/jin/opt/anaconda3
#
#   added / updated specs:
#     - wordcloud
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.11.0               |   py38h50d1736_0        16.9 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        16.9 MB
#
# The following packages will be UPDATED:
#
#   conda                               4.10.3-py38h50d1736_4 --> 4.11.0-py38h50d1736_0
#
#
#
# ...
# conda-4.11.0         | 16.9 MB   | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install jieba
from wordcloud import WordCloud
import PIL.Image as image
import numpy as np
import matplotlib.pyplot as plt
import os
from os import path
import jieba

# %%
path = r'/Users/jin/Desktop/SEM_A/5507-data-acquisition/Group-Assignment/last-coding/ciyuntu0509.csv'
f = open(path,encoding='utf-8')
txt = f.read()

# %%
txt
# Out:
# ',words\n0,半年\n1,涨超\n2,260\n3,倍\n4,一日\n5,跌超\n6,40%\n7,!\n8,马斯克\n9,带货\n10,狗狗币\n11,到底\n12,是不是\n13,骗局\n14,社交\n15,网站\n16,上\n17,宣布\n18,投资\n19,数字\n20,货币\n21,暴富\n22,人\n23,每天\n24,涌现\n25,今年以来\n26,不断\n27,创下\n28,历史\n29,新高\n30,比特币\n31,以太坊\n32,马斯克\n33,推特\n34,日复一日\n35,大肆宣传\n36,狗狗币\n37,成\n38,币圈\n39,新贵\n40,价格\n41,马斯克\n42,言论\n43,涨涨跌跌\n44,狗狗币\n45,是否\n46,真的\n47,具有\n48,投资\n49,价值\n50,半年\n51,涨超\n52,260\n53,倍\n54,一日\n55,跌超\n56,40%\n57,!\n58,马斯克\n59,带货\n60,狗狗币\n61,到底\n62,是不是\n63,骗局\n64,埃隆\n65,马斯克\n66,好不容易\n67,上\n68,一次\n69,周六\n70,夜\n71,现场\n72,SNL\n73,节目\n74,里大谈\n75,狗狗币\n76,区块\n77,链\n78,只能\n79,说\n80,马斯克\n81,砸\n82,盘\n83,表演\n84,很\n85,成功\n86,狗狗币\n87,跟着\n88,大跌\n89,超过\n90,20%\n91,狗狗币\n92,近\n93,6\n94,上涨\n95,近\n96,250\n97,倍\n98,陈一佳\n99,狗狗币\n100,创始人\n101,2015\n102,已\n103,卖光\n104,买币\n105,亏了\n106,4\n107,抗\n108,完全\n109,不\n110,慌\n111,赚\n112,一点\n113,跑\n114,%\n115,韭菜\n116,…\n117,…\n118,…\n119,懂得\n120,自然\n121,懂\n122,孤傲\n123,野\n124,狗狗币\n125,以太\n126,币\n127,…\n128,…\n129,加密\n130,货币\n131,今年\n132,发\n133,洪水\n134,一周\n135,前\n136,刚刚
# ...

# %%
from PIL import Image 
background = Image.open("dollar3.jpg")
graph = np.array(background)

# %%
wcd=WordCloud(font_path=r'/Users/jin/Desktop/SEM_A/5507-data-acquisition/Group-Assignment/last-coding/SourceHanSansCN-Heavy.otf',
              collocations=False,
              width=500,
              height=400,
              background_color='white',
              max_words=100,
              mask=graph,
              scale=1.5).generate(txt)

# %%
wcd.generate(txt)

# %%
wcd.to_file(r"wordcloud0509.png")

# %%
plt.figure("jay")
# 以图片的形式显示词云

# %%
plt.imshow(wcd)
